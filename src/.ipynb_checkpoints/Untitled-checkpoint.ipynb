# %%
# %run -i main.py
# Out:
# Validation character error rate of saved model: 10.624916%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\main.py in <module>
#     145
#     146 if __name__ == '__main__':
# --> 147         main()
#     148
#
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\main.py in main()
#     140         else:
#     141                 print(open(FilePaths.fnAccuracy).read())
# --> 142                 model = Model(open(FilePaths.fnCharList).read(), decoderType, mustRestore=True, dump=args.dump)
#     143                 infer(model, FilePaths.fnInfer)
#     144
#
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\Model.py in __init__(self, charList, decoderType, mustRestore, dump)
#      38                 # setup CNN, RNN and CTC
#      39                 self.setupCNN()
# ---> 40                 self.setupRNN()
# ...

# %%
# %run -i main.py --validate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\main.py in <module>
#     145
#     146 if __name__ == '__main__':
# --> 147         main()
#     148
#
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\main.py in main()
#     134                         train(model, loader)
#     135                 elif args.validate:
# --> 136                         model = Model(loader.charList, decoderType, mustRestore=True)
#     137                         validate(model, loader)
#     138
#
# ~\Desktop\trabajo final IA\SimpleHTR-master\src\Model.py in __init__(self, charList, decoderType, mustRestore, dump)
#      38                 # setup CNN, RNN and CTC
#      39                 self.setupCNN()
# ---> 40                 self.setupRNN()
#      41                 self.setupCTC()
#      42
#
# ...
